# %% [markdown]
# # **TALLER VISUALIZACIÓN PARA CIENCIA DE DATOS EN PYTHON**
#
# ## *Universidad Santo Tomás*
# ### *Gabriela Cortés Merchán*
# ### *Código : $2229034$*

# %% [markdown]
# El objetivo es identificar elementos de una visualización basados en el framework de Tamara para lograr la compresión de todos los componentes claves aprendidos en clase. Para ello el estudiante debe elegir mínimo dos visualizaciones realizadas y publicadas en alguna entidad oficial (ej: páginas gubernamentales, entidades privadas, medios públicos) y analizarlas, cada una, bajo los siguientes criterios:
#
#
# + *Abstraer ¿qué?, ¿por qué? y ¿cómo?*
# + *Marcas y canales utilizados*
# + *Cumple o no cumple alguna de las reglas generales descritas*
# + *Mejoras posibles, en cuánto a marcas o canales, que le realizaría a la visualización*
#
#
# El taller debe ser desarrollado individualmente en un notebook de Jupyter utilizando las herramientas ofrecidas en Markdown, insertando imágenes de las visualizaciones descritas, citando la fuente de dónde fueron extraídas.
#
#
# Debe ser subido a la plataforma oficial en un ‘.zip’ dónde el archivo debe nombrarse así: ‘nombre_apellido_taller1.zip’. Además, el taller debe ser subido a Github para su revisión. Tener en cuenta el plazo de entrega, modificaciones realizadas después de la hora acordada, no se tendrán en cuenta. Seguir las instrucciones garantiza que la calificación sea sobre el puntaje máximo.

# %% [markdown]
# > En el presente trabajo se realizara lo pedido por el docente con dos visualizaciones, en las cuales, su fuente pertenece a los recurso que la docente nos brinda.

# %% [markdown]
# ## Primera visualización

# %% [markdown]
# La primera visualización que va hacer analizada, corresponde a un análisis de tendencia de la trama de todas las películas más taquilleras de los últimos 50 años.
#
#
# Esta visualización hace referencia a poder observar de una manera más interactiva una cronología de las 200 películas más taquilleras de los años 1966 al 2016, con el fin de evidenciar eventos históricos que han tenido las tramas de las películas, al abrir esta página notamos que el autor de esta visualización se plante algunas preguntas, en las cuales se puede evidenciar los cambios que pueden tener las películas, la cinematografía con respecto al ámbito social, polito y cultural, es decir, ¿Que tanto han cambiado las películas con respecto al evento histórico que se evidencie en esa época?, el autor también hace referencia al como obtuvo esa información, lo cual, podemos evidenciar que esta base de datos  la analizaron por medio de palabras claves de la trama de 200 películas principales por taquilla, además, también fue analizada  por ciertos eventos culturales o históricos que fueron relevantes.

# %% [markdown]
# > + *Fuente:*  **["Analyzing plot trends for every top-grossing film from the past 50 years"](https://pudding.cool/2017/06/film-trends/)**

# %% [markdown]
# Antes de analizar los criterios que el análisis de este trabajo requiere  insertaremos algunas imágenes, de cómo se puede observar a primera vista la visualización, en lo cual, notamos que es muy interactiva, es amigable con el usuario, los botones no trasladan a otro sitio se puede elegir por tema y géneros para hacer una búsqueda un poco más rápido si se quiere saber de una película o un tema en particular tiene un sistema de búsqueda por si solo quieres evidenciar esa película y si nos paramos en cualquier punto muestra la ficha técnica de las películas, como evidenciamos en la imagen a  continuación.
#
# > La fuente de la imagen es: **["A Timeline of Each Year’s Top-200 Grossing Films,1966 - 2016"](https://pudding.cool/2017/06/film-trends/)
# ![image.png](attachment:image.png)**

# %% [markdown]
# Podemos evidenciar que a mano izquierda la visualización cuenta con algunos botones el cual muestra algunas de las películas que han ganado premios o que han sido reconocidas.
#
# > La fuente de la imagen es: **["A Timeline of Each Year’s Top-200 Grossing Films,1966 - 2016"](https://pudding.cool/2017/06/film-trends/)
# ![image.png](attachment:image.png)**

# %% [markdown]
# ###  **Abstraer ¿qué?, ¿por qué? y ¿cómo?**

# %% [markdown]
# + **¿Qué?**

# %% [markdown]
# En esta visualización, se puede observar en la parte de Datasets que su tipo de datos son atributos ya que están relacionados con las películas y positions, si observamos en esta visualización los datos están ordenados de menor año a mayor año, y por más que se filtre la visualización siempre quedaran ordenados de esta manera, como importa su orden el tipo de Dataset podría ser un Fields, por otro lado, el tipo de datos de esta visualización también podría ser ítems como lo son el tema y el género de la película y también  podría estar relacionado con un poco de clúster ya que si filtramos los datos por un tema en especial se van a agrupar en un conjunto de datos el cual van hacer homogéneos dentro ya que tendrán en común el género de la película, o tema de la película.
#
# Un ejemplo que podemos observar a continuación de lo dicho anterior mente es una agrupación en tema relacionado con GUNS y con genero ACTION.
#
# > La fuente de la imagen es: **["A Timeline of Each Year’s Top-200 Grossing Films,1966 - 2016"](https://pudding.cool/2017/06/film-trends/)
# ![image.png](attachment:image.png)**
#
# Por otra parte su Dataset Availability es Static, esto porque los puntos sean grandes o pequeños se encontraran  en una única posición y no se pueden mover por más que se filtre o interactúe con la visualización.
# Continuando con los Atributes, podemos mencionar que son tipo de atributos ordenados ordinal, ya que los puntos hacen referencia  a que entre más grande el punto más taquillera fue la película, no se puede mencionar que es ordenada cuantitativa porque bien menciono el autor que este análisis se hizo a través de palabras claves, por ultimo su orden de dirección es secuencial ya que parte del año 1966 y a medida que se bajó los años van aumentando.

# %% [markdown]
# + **¿Por qué?**

# %% [markdown]
# Analizando el ¿por qué? hay que recordar que existen en esta línea verbos que describen acciones y sustantivos que describen objetos.
# Pasando a la parte de verbos, las acciones que se pueden evidenciar en esta visualización son; que es un medio de consulta para identificar las películas más taquilleras en diferentes años, conjuntamente no se recomienda pero  si el usuario lo requiere este medio de consulta también sirve para comparar entre años pero para esta visualización el tema de comparar es un poco más complejo ya que al haber tantos años no se puede observar una comparación  muy precisa, por eso, en mi opinión esta visualización es de Query – Indentify de igual manera también  puede ser un Query – Summarize  ya que cada película resume en el ranking que se encuentra, lo que recaudo, las palabras claves en su búsqueda, los votos que esta película tuvo y si paso algo extraordinario en esa película. Además, es un search – lookup ya que sirve para buscar que película gano un premio o cuanto se vendió en taquilla entre otros, pero si ese no es nuestro objetivo podria ser una search - explore, por ultimo podemos decir que otro verbo es que esta visualización es de consumo Discover, ya que tú vas explorando el punto el cual quieras ver información, de palabras claves ganancia entre otros.
# Por otra parte se encuentra los sustantivos la descripción de los objetos, en mi opinión toda la data viene dada por trends (tendencia), esto porque si hay una tendencia en esa película, como lo es el  crecimiento de la audiencia, es muy buscada, entre otros,  el circulo se va volviendo más grande, por otra parte sus atributos son de similitud, en le cual se evidencia la clasificación anual, los votos, las palabras claves de cada película.

# %% [markdown]
# + **¿Cómo?**

# %% [markdown]
# El cómo de esta visualización viene dado por un Encode de tamaño el cual se puede evidenciar en los círculos,  también se puede evidenciar un Encode de color, el cual representa; El color  rojo representa los grupos cuando se filtra por temas o genero de películas iguales, de igual manera todos estos círculos son crises, pero al pararte en ellos bota un color verde que simboliza que estas observando esa película en la cual te encuentras parado. También tiene un Encode - Arrange de orden en el tiempo, por otra parte la forma de manipulación de esta visualización es select ya que el usuario selecciona el punto que quiere ver sea grande o pequeño, y otra cosa que podemos encontrar en este como es que tiene un Reduce por Filter, ya que, si solo quieres ver un género de película puedes filtrar estos círculos o por el contrario si quieres solo ver un tema en especial.

# %% [markdown]
# ### Marcas y canales utilizados

# %% [markdown]
# <div style="text-align: justify">En esta visualización podemos encontrar marcas de tipo áreas y conjuntamente los canales que se evidencia en esta visualización son  de posición  espacial both, ya que los círculos están ordenados tanto vertical como horizontal mente, también tiene un canal de color para los atributos, en el cual a simple vista es gris, pero puede ser verde si se para en el punto, o rojo si el usuario filtro el interés, otro canal que se puede evidenciar es el tamaño, en el cual se evidencia  el área del circulo por lo antes ya mencionado.
# Además también podemos evidenciar una eficacia y efectividad en la visualización dado que expresa toda la información pero de una forma en que  los atributos más importantes en este caso las películas más taquilleras se evidencia de una forma más notoria en  esos canales. Según el ranking de canales tiene una eficacia alta dado por el color, pero media dada por el área.
# Por otra parte en la eficiencia podemos observar que la precisión en  las áreas circulares no está en la mejor posición, por otra parte tiene una buena discriminabilidad visual, donde cada elemento es un paso o nivel distinguible del otro, aunque se podría mejorar. Tiene una separación de alguna interferencia por los tonos de color, tiene un popout bueno a simple vista pero cuando se filtran por temas el popout no es tan buena ya que hay mucha interferencia, su agrupación en marca de elementos está dada por áreas que en este caso son los círculos y por color, no tiene una buena proximidad pero trata de hacer cierta similitud en los filtros.<div/>

# %% [markdown]
# ### Cumple o no cumple alguna de las reglas generales descritas

# %% [markdown]
# Como se puede observar en las imágenes que se presentaron  al principio de la descripción de la visualización estos  círculos están en formato 2D en este caso está justificado, dado que el autor tiene como objetivo demostrar las películas más relevantes, pero esto él lo hace en un top de 200 películas más taquilleras es aquí donde las películas que tienen el circulo muy pequeño pueden pasar desapercibida y se puede perder información de estas películas, dado que como usuario lo primero que uno ve son las grandes las de mayor área y se observa que información tiene pero aquellas películas que tienen un circulo muy pequeño como usuario no las voy a ver dado que son muchas películas y por mi parte pasan desapercibido así que como usuaria para mi puede estar injustificado esta acción, porque en 50 años si nos ponemos a observar sacan muchas películas, demasiadas y un top de 200 es considerable, pero si no observamos estas pequeños círculos estas que están en el top pero al final, es como si estas películas pasaran desapercibida y debes de un top 200 se evidencie solo un top 20 por ejemplo.
# Por otra parte la regla de los ojos le ganan a la memoria, personalmente también se ve interrumpida, dado que al ser tantas películas en un solo lado y sin tener conocimiento previo de que quiero buscar o conocimiento en películas al ver tantos círculos en un solo lado, visualmente cansa, esto porque voy a ver los primeros puntos, los más relevantes y de pronto los últimos, pero los que están en años por ejemplo 2005 a 2010 esa información se pierde por que visualmente cansa esa visualización.
# Personalmente la resolución sobre la inmersión también se puede estar viendo afectado, el  por qué, es porque  el autor de esta visualización hace referencia con imágenes a ciertas películas que tuvieron algún premio, algún reconocimiento o algún hecho histórico - cultural importante como se muestra a continuación:
#
# > La fuente de la imagen es: **["A Timeline of Each Year’s Top-200 Grossing Films,1966 - 2016"](https://pudding.cool/2017/06/film-trends/)
# ![image.png](attachment:image.png)**
#
# Como lo podemos observar al estar en círculos medianos - pequeños no son tan evidentes, ahora pensemos en el caso en que lo vea en una pantalla pequeña ejemplo el celular al no moverse si este círculo estuviera un poco más alejado se puede perder esta información visual.

# %% [markdown]
# ### Mejoras posibles, en cuánto a marcas o canales, que le realizaría a la visualización

# %% [markdown]
# Personalmente las mejorías que yo le haría a esta  visualización seria separa los años,por ejemplo por filtros, dado que no observamos el corte de todos los años si no se observa el corte de ciertos años, de esta manera no se evidencia muy bien que películas corresponden a qué año, claro esto lo haría si el objetivo sería mirar las películas más taquilleras por año. Otra mejoría que yo le hubiera hecho es quitar el 2D o si es necesario  dejarlo hacer una forma más interactiva es decir repartir a un grupo las películas más taquillas, a otro las películas que se encuentran en la mitad y a otro las que menos son taquilleras con base en el top, o si se quisiera dejar los puntos de esa manera como se encuentran, seria  ordenarlos de izquierda a derecha, de mayor a menor, porque si observamos hay algunos puntos que son pequeños y al tener al lado uno grande ese punto desaparece visualmente, otro arreglo que le haría sería no dejar todas las películas en un mismo sitio, sino que a medida que vas bajando o espichando el usuario pueda interactuar y no sea una mancha llena de círculos, otro arreglo personal que le haría sería dejar las imágenes en una ventanita que se habrá al  espichar el botón y se vea, para que de esta manera sea más clara y este más grande y no dependa del tamaño del círculo, tal vez se puede hacer una mejor visualización con estos datos, pero cabe aclarar que el autor hizo un buen trabajo.

# %% [markdown]
# ## Segunda visualización

# %% [markdown]
# La siguiente visualización que analizaremos para esta trabajo, también fue suministrada por los recursos que la docente nos permitió, la página se llama [information is beautiful]( https://informationisbeautiful.net/data/) y lo que podemos notar es que es una página publica con variedad de datos, los cuales, se pueden evidenciar en enlaces bit.ly, ya que, además de brindarnos la visualización también nos brinda el suministro de donde fueron sacados estos datos, es porque manejan datos públicos, además, esta página nos dice que el  80% de la información con que ellos cuentan están involucradas en información de infografías, por ultimo esta página tiene como misión extraer los datos, la información y el conocimiento del mundo en infografías y visualizaciones.

# %% [markdown]
# Ahora bien hablaremos sobre la visualización, esta visualización a simple vista parece muy buena, y cuenta con mucha información relevante, la idea de esta visualización es mostrar los científicos inconformistas cuyas ideas heréticas finalmente demostraron ser correctas, pero bien hay que tener en cuenta que herética proviene de la pabla herejías, donde herejía “Se entiende por  la contraposición a un grupo o conjunto de ideas que se tienen en relación a aquellas creencias que han sido consideradas irrevocables e inmutables por un grupo de personas en un tiempo o época determinada.” **[Significado herejía]( https://www.significados.com/herejia/)**
#
# Ya al tener este concepto en mente, podemos seguir mirando que tiene esta visualización y que otras finalidades tiene el autor.  Como podemos evidenciar esta visualización también cuenta con ciertos filtros y botones, lo cual permite hacer una visualización un poco más interactiva con el usuario, alguno de estos filtros es que puedes  seleccionar en campos de interés  como lo son  la astronomía, biología, ingeniería, matemáticas, medicina  y ciencias físicas, algo que se nota en particular, es que cada uno de estos campos esta diferenciado por color y otra cosa particular que tiene esta visualización es que los autores están ordenados por la primera inicial alfabéticamente. También es claro aclarar que este orden también se puede cambiar por año de herejía sea en orden ascendente o descendente, el nombre también puede ser cambiado de Z – A o A – Z, otros ordenes que puede tener es por edad de herejía, años parias, reacción, o el aporte que tuvo  hoy en día, como podemos observar siempre va a estar ordenado según los requerimientos que quiera el usuario. Esto puede ser observado a continuación para el caso de medicina:
#
# > + *Fuente de la imagen:* **["Mavericks y heretics"]( https://informationisbeautiful.net/visualizations/mavericks-and-heretics/)**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# También podemos observar que el campo de matemáticas visualmente no se encuentra ningún personaje, como podemos observar a continuación:
#
# > + *Fuente de la imagen:* **[Mavericks y heretics]( https://informationisbeautiful.net/visualizations/mavericks-and-heretics/)**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Ahora bien aparte de la visualización, algo interesante que tiene esta página y no lo tenia la otra, es que podemos ver los datos que fueron utilizados para esta visualización, algunos de los datos son los siguientes:
#
# > +	*Fuente imagen:* **[Mavericks y Heretics - public data]( https://docs.google.com/spreadsheets/d/1x2queTl7dN7illZgOfvZB6aGe9nPVjo-JlEdUY8CbJU/edit#gid=0)**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Algo que también podemos observar en este libro de cálculo, es que podemos observar el análisis que se hizo a los datos recolectados en la visualizacion y que también se encuentran en la visualización, pero en una forma más arreglada, en este análisis, se muestran diferentes ítems, como lo son; Disciplina mas viciosa, años promedio de paria, edad promedio de herejía, reconocimiento y más tiempo para reconocer,  este análisis que el autor o autores hicieron, está relacionada con algunos análisis descriptivos para el promedio, mediana y moda, algunos de los datos que están representados en este análisis no son muy claros de donde fueron sacados, lo antes mencionado se puede evidenciar a continuación:
#
# > + *Fuente imagen:* **[Mavericks y Heretics - public data]( https://docs.google.com/spreadsheets/d/1x2queTl7dN7illZgOfvZB6aGe9nPVjo-JlEdUY8CbJU/edit#gid=186012113)**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Algo que también se puede observar es que el autor(es) aparte de mostrar visualmente los datos  también va dando  conclusiones y comentarios relevantes que se destaca del estudio. Y para finalizar esta visualización da ciertos datos que pueden ser interesantes para el usuario, como se muestra a continuación:
#
# > + *Fuente de la imagen:* **[Mavericks y heretics]( https://informationisbeautiful.net/visualizations/mavericks-and-heretics/)**
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Por último, cabe aclarar que algo bueno que tiene esta visualización es que si quieres conocer más del personaje espichando la fotografía te manda a un link de Wikipedia para dar su biografía, reconocimientos, investigaciones, entre otras.

# %% [markdown]
# >> + *Fuente:*  **["Mavericks & heretics"](https://informationisbeautiful.net/visualizations/mavericks-and-heretics/)**

# %% [markdown]
# ###  **Abstraer ¿qué?, ¿por qué? y ¿cómo?**

# %% [markdown]
# + **¿Qué?**

# %% [markdown]
# Para la visualización antes mencionada se puede observar que el tipo de data  son positions, ya que como lo mencionamos anterior mente la primera visualización siempre va a estar ordenada depende del requerimiento, también encontramos tipos de datos de tiempo, como lo son los años, y además también hay ciertos atributos e ítems como lo son el nombre, la edad, su pensamiento, lo que realizo, lo cual  tiempo después fue utilizada en estudios o fue meritoria para premios nobel, por lo anterior decimos que puede ser un tipo de Dataset temporal, ya que se tiene ítems, atributos y tiempo, sobre todo cuando se  observa la base datos, se encuentra ese tipo de datos, conjuntamente también podríamos decir que puede ser un Dataset Fields ya que si recordamos lo que dijimos anteriormente el usuario puede ordenar según el requerimiento si lo quiere por nombre, fecha, entre otros, por otra parte, esta visualización tienen un Dataset Availability - Dinamic esto se puede decir por qué si se filtra la información por campos de investigación la información va cambiando dinámicamente, incluso por lo que mencionamos anteriormente que al espichar una fotografía esta te lleva a otro sitio donde se puede visualizar más información. Por otra parte los tipos de atributos son ordenados cuantitativos y el orden de dirección es Diverging, cabe aclarar, que  todo lo anterior se hizo con base a la siguiente visualización.
#
# > + *Fuente de la imagen:__Visualización 1__* **[Mavericks y heretics]( https://informationisbeautiful.net/visualizations/mavericks-and-heretics/)**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Pero si recordamos esta visualización representa otros análisis, que pueden ser otras visualizaciones, como la que vamos a ver a continuación . Como notamos estas visualización tiene tipo de Data  ítems y atributos, por lo cual su Dataset es una tabla, y su Dataset availability es Static, y conjuntamente sus atributos son ordenados ordinal, ya que si notamos están ordenados pero son categóricos, y si dirección de orden es secuencial ya que cada punto representa la persona con dichas características y en esas características pueden haber más personas, esta visualización la observamos a continuación.
#
# > + *Fuente de la imagen:__Visualización 2__* **[Mavericks y heretics]( https://informationisbeautiful.net/visualizations/mavericks-and-heretics/)**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Por otra parte también se puede visualizar tipos de Data en lista, estos pueden estar relacionados con un tipo de Dataset Trees, por su forma de unión ya que uno distintos ítems con distintos atributos, su Dataset availability en este caso también es Static y sus atributos en esta caso son categóricos, esta visualización la podemos observar a continuación.
#
# > + *Fuente de la imagen:__Visualización 3__* **[Mavericks y heretics]( https://informationisbeautiful.net/visualizations/mavericks-and-heretics/)**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Por último, encontramos también un Dataset tipo Geometry, con un Dataset Availability Static, con atributos ordenados cuantitativamente y con dirección ordenada secuencial, esta visualización es la siguiente:
#
# > +	*Fuente de la imagen:__Visualización 4__* **[Mavericks y heretics]( https://informationisbeautiful.net/visualizations/mavericks-and-heretics/)**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# + **¿Por qué?**

# %% [markdown]
# Cabe aclarar que el ¿por qué? de un framework está basado en un conjunto de verbos que describen las acciones y sustantivos que describen objetivos, ahora bien ya recordando eso, las visualizaciones se marcaron como visualización 1, visualización 2, visualización 3 y visualización 4 para analizar el ¿por qué?, una por una, y no colocar tantas veces la misma imagen, aclarando lo anterior continuemos en el análisis del framework.
#
#
#
#
# + **Visualización 1:**
# En esta visualización podemos evidenciar que las acciones es decir los verbos pueden ser; Que es una visualización de consumo la cual sirve para explorar los autores relevantes que se encuentran en la visualización, además también puede ser de consumo Enjoy ya que si se está interesado en cierto personaje puedes con un clic saber más sobre este personaje, por otra parte, su Search es un Browse, ya que se desconoce el target pero si se tiene conocimiento previo de ciertos personajes su Location seria conocida y serviría para navegar, pero además puede ser un Explore, ya que, si no se tienen como tal conocimiento previo tu puedes interactuar y explorar esta visualización, por otro lado, su Query es de comparar, ya que, se puede comparar por  ejemplo personajes de astronomía en sus diferentes años o personajes de la historia por su edad de herejía.
# Continuando con la visualización una para la parte de sustantivos podemos decir que  toda la data son Features, tienen Many atributos en estos atributos se puede evidenciar similitud y puede que tenga un poco de datos de red en Topology.
#
#
# - **Visualización 2:**
# Algunas acciones para esta segunda visualizaciones  es que es de análisis de consumo Present (explicar) es un Search - Browse y es un Query - Summarize dado que resume el conjunto de datos para esas variables categóricas, y algunos de sus objetivos  en toda su Data puede ser de tendencia, dado que, si observamos las ciencias van teniendo cierta tendencia en la medicina, los atributos son muchos y están relacionados con similitud.
#
#
# + **Visualización 3:**
# El ¿Por qué? De esta visualización está dado por una acción de  Consume -  Present , su Search es Locate  dado que está localizando ciertas características por cada una de las ciencias, por otra parte su Query viene dado por Compare, dado que, al tener ya sus características, estas se pueden visualizar al mismo tiempo y compararlas, y por otro lado, en su targets sus objetivos son de datos en redes – Paths, dado que, entre sí, no se unen, pero si tiene sus destinos.
#
#
# + **Visualización 4:**
# La ultima visualización que pudimos comparar tiene acciones de;  Analyze – Consume – Discover, un Search  Lookup y un Query – Compare, por otra parte su targets sus sustantivos vienen dados por atributes – One – Distribution y  toda su data pueden ser tendencias.

# %% [markdown]
# + **¿Cómo?**

# %% [markdown]
# Para analizar el cómo de igual manera lo aremos visualización por visualización.
#
# + **Visualización 1:**
# La primera visualización está dada por un Encode – Arrange -  Express y de Order, esto porque si observamos el orden, solo los años, nombre del personaje, herejía y demás, lo rápido está en que te puede movilizar de ciencia a ciencia, es decir, solo quiero ver ingeniería y después astronomía y las demás no me interesan, claro esta es un ejemplo, conjuntamente al Encode, también se diferencia por color tiene un Hue, para todas las ciencias en las cuales se está evaluando. Por otra parte, permite que el usuario manipule seleccionando y navegue por otras páginas para obtener más información, el  Facet es una Partition  y el autor lo reduce a través de Filter.
#
#
# + **Visualización 2:**
# Para esta visualización  el Encode- Arrange también puede ser de Order, también se diferencian por color los resultados según la ciencia y además tiene un Shape, el autor no permite que esta visualización se manipule, pero si se evidencia un Facet de Superimpose, ya que, se están comparando dos cosas distintas en una sola.
#
#
# + **Visualización 3:**
# Para esta visualización se tiene un Encode – Map el cual, se diferencia los datos por el color- Hue, de igual manera que la visualización dos no permite ser manipulada, tiene un Faces de Partition esto porque se separan las ciencias.
#
#
# + **Visualización 4:**  Para esta última visualización Se tiene un Encode – Align  y de Order por el eje x, no permite ser manipulada.

# %% [markdown]
# ### Marcas y canales utilizados

# %% [markdown]
# Dado que las marcas son elementos gráficos podemos notar que para la *Visualización 1* está dada por líneas, por el contrario la *Visualización 2* tiene una marca de puntos, la *Visualización 3* una marca de líneas  y la *Visualización 4* tiene una marca de igual manera en líneas dado que es un gráfico de barras. Conjuntamente el canal de la *Visualización 1* está dada por una position horizontal y por color para los atributos, además tiene un canal de Size – length , por el contrario la  *Visualización 2* está dada por un canal de posición espacial, vertical por ítem y horizontal por atributo, además, se evidencia un canal de color para cierto atributos categóricos, continuando la *Visualización 3*  tiene un canal de color para los atributos categóricos, extendiendo, la  *Visualización 4* tiene un canal de posición espacial vertical para el atributo cuantitativo y un canal de posición espacial horizontal para el atributo categoría ( rango de edad).
#
#
# Permaneciendo con el análisis, se observa una efectividad en las visualizaciones, pero la eficacia no es muy notoria pero puede que la tenga. Basándonos en  el ranking de canales podemos notar que la posición  en escala no lineal para la primera visualización según el ranking tiene mayor eficacia y conjuntamente el color ayuda bastante, para las otras visualizaciones, el tono de color ayuda para una mayor eficacia, es decir, tiene una buena eficacia, ya que si lo observamos siempre utilizan las mismas tonalidades por lo cual no se pierde el contexto del color.
#
#
# Ahora bien, al observar la eficiencia del canal  la visualización 4 está en las que tiene mejor precisión, la visualización 3 no aparece en esta precisión, continuando, estas visualizaciones  tienen una buena discrinabilidad, pero bien, hablemos de la separabilidad en las tres primeras visualizaciones al separar los ítems por colores, no permiten tener interferencias en la visualización, es decir, esto es muy bueno, tiene un buen popout dado que cada visualización es distinta se lleva un hilo en cada una  y en la visualización principal se diferencia bien las cosas a excepción de las linead que suelen ser muy largas y no son muy entendibles. Por otra parte la agrupación ya fue mencionada en el primer párrafo el cual se evidencia que trabajan con puntos y líneas según el objetivo de estudio y trabajan mucho con el color, y eso permite una mejor visualización.

# %% [markdown]
# ### Cumple o no cumple alguna de las reglas generales descritas

# %% [markdown]
# La visualización no presenta injustificación 3D en ninguna de las visualizaciones, conjuntamente las tres primeras visualizaciones no tienen tampoco 2D, la última visualización, el grafico de barras tiene una visualización 2D pero está justificado y no se ve una pérdida de información, por lo contrario este grafico se adapta a la tarea de ese análisis en particular, la regla de los ojos le ganan a la memoria no se ve muy afectada pero personalmente si le veo algo particular que le hace falta a esta visualización, el cual es, que para la primera visualización la herejía que propuso ese personaje queda muy pegado del que dijo el otro personaje, esto puede que cause confusiones en el usuario, conjuntamente, algo que vi que como usuaria, que  no me quedo muy claro es la repartición de esta línea horizontal divergente, dado que va para ambos lados y se pasa de los valores que se muestran en la parte superior, como lo notamos a continuación, y siguiendo con las reglas de resolución sobre la inmersión en mi opinión está muy bien ya que si no puedo ver bien el personaje por que el tamaño está muy pequeño, si le espicho a este personaje, aparte de que lo voy a   ver mejor me bota más información, que personalmente eso me parece muy bueno.
#
# > + *Fuente de la imagen:* **[Mavericks y heretics]( https://informationisbeautiful.net/visualizations/mavericks-and-heretics/)**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Mejoras posibles, en cuánto a marcas o canales, que le realizaría a la visualización

# %% [markdown]
# Personalmente esta visualización me parece que quedo muy bien realizada, la verdad me gustó mucho, no le haría muchas mejoras por que personalmente me parece que quedo muy bien, es así, que las mejoras que yo le aria seria brindar más espacio entre los autores esto porque  si la quiero ver en un ordenador más pequeño tanta palabra tan pegada cansa visualmente sin ni siquiera leerla, es decir, la vi por el celular y desde el celular se puede observar de una mejor manera, sería buena que lo arreglan así también para el ordenador,  por otra parte arreglaría  los valores del eje x para la visualización 1 que no vayan de 10 en 10 hasta 70 si no que sean un poco más grandes para que todas las líneas o flechas se evidencien dentro de esta información y que no se salgan y se pierda el contexto, del resto me parece que los colores, la organización, la explicación y todo en general, está muy bien realiza.

# %% [markdown]
# ### Gracias
# <gabriela.cortes@usantotomas.edu.co>
